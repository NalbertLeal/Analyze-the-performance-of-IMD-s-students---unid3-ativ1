# %%
# Import necessary module
from sqlalchemy import create_engine
import pandas as pd

# Create engine: engine
engine = create_engine('sqlite:///programming.sqlite')

# %%
# Import BoxPlot, output_notebook, and show from bokeh.charts
from bokeh.charts import BoxPlot, Donut, Bar, Histogram, output_notebook, show
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.layouts import gridplot, row
from bokeh.models import HoverTool
from bokeh.models.widgets import Panel, Tabs
from bokeh.plotting import ColumnDataSource

# %%
# What are the tables in the database?

# Save the table names to a list: table_names
table_names  = engine.table_names()

# Print the table names to the shell
print(table_names)

# See the data model here: http://chinookdatabase.codeplex.com/wikipage?title=Chinook_Schema&referringTitle=Home
# Out:
# ['Grade']

# %%
# The power of SQL lies in relationships between tables: INNER JOIN

# Execute query and store records in DataFrame: df
df = pd.read_sql_query("select * from Grade",engine)

# drop the unnecessary column
df = df.drop('index', 1)

# print the number of unique students
print(len(df['Aluno_ID'].unique()))

# Print head of DataFrame
df.head()
# Out:
# 766
#    Aluno_ID  Período                                         Disciplina  \
# 0         0   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 1         1   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 2         2   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 3         3   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 4         4   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
#
#    Situaçăo  Média Final  Unidade I  Unidade II   Unidade III
# 0  APROVADO          7.0        4.9          9.0          7.0
# 1  APROVADO          7.3        8.0          7.0          7.0
# 2  APROVADO          9.3        9.5          8.3         10.0
# 3  APROVADO          7.3        6.5          7.0          8.3
# 4  APROVADO          7.5        5.5          8.0          9.0

# %% [markdown]
# ### Informações do Banco de dados
#
# - Colunas:
#  - Aluno_ID
#  - Período
#  - Disciplina
#  - Situaçăo
#  - Média Final
#  - Unidade I
#  - Unidade II
#  - Unidade III
# - Nome das disciplinas:
#  - IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
#  - IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO
#  - IMD0029 - ESTRUTURA DE DADOS BÁSICAS I
#  - IMD0030 - LINGUAGEM DE PROGRAMAÇĂO I
#  - IMD0039 - ESTRUTURAS DE DADOS BÁSICAS II
#
# - numero de alunos = 695

# %% [markdown]
# ## Média final de disciplinas por semestre

# %%
#Valores das matérias no primeiro período
with engine.connect() as con:
    rs = con.execute("SELECT \"Média Final\", Disciplina, Período FROM Grade")
    
    df2 = pd.DataFrame(rs.fetchall())
    df2.columns = rs.keys()

# Print head of DataFrame
df2.head()
# Out:
#    Média Final                                         Disciplina  Período
# 0          7.0  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 1          7.3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 2          9.3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 3          7.3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 4          7.5  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1

# %%
df2.info()
df2 = df2[df2['Média Final'].notnull()]
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3476 entries, 0 to 3475
# Data columns (total 3 columns):
# Média Final    2963 non-null float64
# Disciplina     3476 non-null object
# Período        3476 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 81.5+ KB
#    Média Final                                         Disciplina  Período
# 0          7.0  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 1          7.3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 2          9.3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 3          7.3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 4          7.5  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1

# %%
# Make a box plot: p
p = BoxPlot(df2, values='Média Final', label='Disciplina', color='Disciplina',
             title='Distribuição da média de notas das disciplinas',
             legend='top_left')

# Set the y axis label
p.yaxis.axis_label='Média por período'
p.plot_width=1000
p.plot_height = 1000

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="353db048-18cd-4706-819b-82316f0b636c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8eeafc85-d2f4-492f-b3ea-c50ea01457a2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8eeafc85-d2f4-492f-b3ea-c50ea01457a2").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8eeafc85-d2f4-492f-b3ea-c50ea01457a2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8eeafc85-d2f4-492f-b3ea-c50ea01457a2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"102a13bc-b8aa-41d0-b1d8-900379d367b8":{"roots":{"references":[{"attributes":{"data_source":{"id":"52224e6d-f05c-4063-be97-ec378074ee2e","type":"ColumnDataSource"},"glyph":{"id":"b23603f2-4410-4363-a37c-41e9412fc5b2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b96a25b2-9bbd-4696-9951-7eff761e079a","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"3afd1b6a-d0dd-413c-923a-7aef0678b51c","type":"Segment"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Disciplina":["IMD0012.1 - PR\u00c1TICAS DE T\u00c9CNICAS DE PROGRAMA\u00c7\u0102O"],"chart_index":[{"Disciplina":"IMD0012.1 - PR\u00c1TICAS DE T\u00c9CNICAS DE PROGRAMA\u00c7\u0102O"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[3.8],"label":[{"Disciplina":"IMD0012.1 - PR\u00c1TICAS DE T\u00c9CNICAS DE PROGRAMA\u00c7\u0102O"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["IMD0012.1 - PR\u00c1TICAS DE T\u00c9CNICAS DE PROGRAMA\u00c7\u0102O"],"y":[2.9]}},"id":"c69a10f0-6593-4e52-ac44-c9d004073313","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d9d1c12-8b83-4afa-8065-84dc138ce32e","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"0db12a52-1f6a-49b6-a837-0f7c826c5304","type":"Segment"},{"attributes":{"data_source":{"id":"5c420ee0-3cb8-44ee-9db8-b569032c0e80","type":"ColumnDataSource"},"glyph":{"id":"f6bda4cb-031d-43ef-bfc8-827474a54566","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9b17b657-7d41-4d73-af53-2f379af157b6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Disciplina":["IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"],"chart_index":[{"Disciplina":"IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[1.0499999999999998],"label":[{"Disciplina":"IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"],"y":[7.025]}},"id":"14d8c9e6-81f4-4a04-b920-034004bdac83","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"39c53285-c29b-4a47-ba16-0d58977728a6","type":"Rect"},{"attributes":{"data_source":{"id":"8ed2a59f-a82e-4c3f-a65f-2c9a29a5732b","type":"ColumnDataSource"},"glyph":{"id":"3afd1b6a-d0dd-413c-923a-7aef0678b51c","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8600e52b-2481-4255-9e59-8ee02b8ab094","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c69a10f0-6593-4e52-ac44-c9d004073313","type":"ColumnDataSource"},"glyph":{"id":"39c53285-c29b-4a47-ba16-0d58977728a6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3235ff5b-711b-42c3-8bb1-6c148e3b14ee","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"14d8c9e6-81f4-4a04-b920-034004bdac83","type":"ColumnDataSource"},"glyph":{"id":"3d9d1c12-8b83-4afa-8065-84dc138ce32e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e8b019b2-85a7-43bd-82b5-f4bcd0118c85","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"Disciplina": ...

# %%
#Valores das Notas por unidades
with engine.connect() as con:
    rs = con.execute("SELECT \"Unidade I\", \"Unidade II\", \"Unidade III\", Disciplina, Período FROM Grade")
    
    df_unidades = pd.DataFrame(rs.fetchall())
    df_unidades.columns = rs.keys()

# Print head of DataFrame
df_unidades.head()
# Out:
#    Unidade I "Unidade II"  Unidade III  \
# 0        4.9   Unidade II          7.0
# 1        8.0   Unidade II          7.0
# 2        9.5   Unidade II         10.0
# 3        6.5   Unidade II          8.3
# 4        5.5   Unidade II          9.0
#
#                                           Disciplina  Período
# 0  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 2  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1
# 4  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1

# %% [markdown]
# ## Relação de reprovados e unidades com mais baixo desempenho

# %% [markdown]
#     - Serão colhidos dados do banco de dados e esses dados serão usados para descobrir qual a unidade que foi mais dificil para os alunos na matéria que teve mais alunos reprovados.

# %%
import numpy as np

def get_data_from_db():
    """ Faz uso de uma query para buscar no banco as colunas desejadas. """
    df3 = pd.read_sql_query("SELECT Disciplina, Período, Situaçăo,\"Média Final\", \"Unidade I\", \"Unidade II\", \"Unidade III\" from Grade",engine)
    df3 = df3[df3['Situaçăo'] == 'REPROVADO']
    df3 = df3[df3['Situaçăo'].notnull()]
    return df3
    
def descobrir_disciplinas(df):
    lista_disciplinas = []
    for index in range(len(df)):
        try:
            disciplina = df.ix[index, 'Disciplina']
            if disciplina not in lista_disciplinas:
                lista_disciplinas.append(disciplina)
        except KeyError:
            continue
    return lista_disciplinas

def descobrir_periodos(df):
    lista_periodos = []
    for index in range(len(df)):
        try:
            periodo = df.ix[index, 'Período']
            if periodo not in lista_periodos:
                lista_periodos.append(periodo)
        except KeyError:
            continue
    return lista_periodos

def descobrir_maior_numero_reprovados(df, disciplinas):
    maior_numero = {'Disciplina': '', 'Período': 0, 'Numero de alunos': 1000000, 'Dataframe': 0}
    for disciplina in disciplinas:
        df2 = df[df['Disciplina'] == disciplina]
        if maior_numero['Numero de alunos'] > len(df2):
            maior_numero['Disciplina'] = disciplina
            maior_numero['Numero de alunos'] = len(df2)
            maior_numero['Dataframe'] = df2
    return maior_numero

def media_unidades(dicionario):
    media_final = dicionario['Dataframe']['Média Final'].sum() / dicionario['Numero de alunos']
    unidadeI = dicionario['Dataframe']['Unidade I'].sum() / dicionario['Numero de alunos']
    unidadeIII = dicionario['Dataframe']['Unidade III'].sum() / dicionario['Numero de alunos']
    return {'media_final': media_final, 'unidadeI': unidadeI, 'unidadeIII': unidadeIII}
    
###########################################

def discover_smaller_media_final(df):
    smaller = 20 # a maior nota é 10, colocando 20 então certamente esse valor inicial não influenciará em nada o resultado
    for index in range(len(df)):
        try:
            if smaller > df.ix[index, 'Média Final'] and df.ix[index, 'Média Final'] > 0.0:
                smaller = df.ix[index, 'Média Final']
        except KeyError:
            continue
    return smaller

def get_row_smaller_media_final(df, smaller):
    df2 = df[df['Média Final'] == smaller]
    return df2

# %%
df3 = get_data_from_db()
df3.head()
# Out:
#                                            Disciplina  Período   Situaçăo  \
# 30  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 31  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 32  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 33  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 34  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
#
#     Média Final  Unidade I "Unidade II"  Unidade III
# 30          2.0        1.4   Unidade II          0.0
# 31          1.4        4.3   Unidade II          0.0
# 32          3.8        4.8   Unidade II          2.5
# 33          2.2        3.1   Unidade II          1.0
# 34          1.5        2.9   Unidade II          0.0

# %%
lista_disciplinas = descobrir_disciplinas(df3)
lista_disciplinas
# Out:
# ['IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO',
#  'IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO']

# %%
disciplina_maior_reprovados = descobrir_maior_numero_reprovados(df, lista_disciplinas)

# Coloca na tela o head de do "dataframe" da matéria com mais reprovados
print('Numero de alunos: ', disciplina_maior_reprovados['Numero de alunos'], '\n')
disciplina_maior_reprovados['Dataframe'].head()
# Out:
# Numero de alunos:  95
#                                          Disciplina  Período   Situaçăo  \
# 86  IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 87  IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 88  IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 89  IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
# 90  IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO   2014.1  REPROVADO
#
#     Média Final  Unidade I "Unidade II"  Unidade III
# 86          2.8        8.5   Unidade II          0.0
# 87          4.2        6.8   Unidade II          3.9
# 88          0.7        2.0   Unidade II          0.0
# 89          0.2        0.5   Unidade II          0.0
# 90          2.5        4.3   Unidade II          0.0

# %%
lista_periodos = descobrir_periodos(disciplina_maior_reprovados['Dataframe'])
lista_periodos
# Out:
# [2014.0999999999999]

# %%
medias = media_unidades(disciplina_maior_reprovados)

print('Nome da matéria com mais reprovados: ', disciplina_maior_reprovados['Disciplina'])
print('Media da matéria: ', medias['media_final'], '\nMedia da Unidade I: ',  medias['unidadeI'], '\nMedia da Unidade III: ', medias['unidadeIII'])
# Out:
# Nome da matéria com mais reprovados:  IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO
# Media da matéria:  2.0842105263157893
# Media da Unidade I:  3.4315789473684215
# Media da Unidade III:  1.3473684210526313
